# %%
# !pip install mne
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.7/dist-packages (0.22.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from mne) (1.19.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from mne) (1.4.1)

# %%
import mne
import numpy as np
import os
import h5py

# %%
os.chdir('/content/drive/MyDrive/ECE-GY_9123_DL')
# !wget -r -N -c -np https://physionet.org/files/eegmmidb/1.0.0/

# %% [markdown]
# # Assistant self-defined functions

# %%
def loadEEG(subject):

  """
  
  """
  subject_str = 'S{:03d}'.format(subject)
  dataPath = '/content/drive/MyDrive/ECE-GY_9123_DL/project/data'
  print('\n Subject {} loading ... \n'.format(subject))

  # load files from subject folder
  dataFolder_s = os.path.join(dataPath, subject_str)
  fileNames = sorted([f for f in os.listdir(dataFolder_s) if f.endswith('edf')],
                    key=lambda x: x[-2:])

  sr = 160
  start_ind = list(range(0, 168, 14))       # start index of each file
  raw_eeg_s = np.empty((168, 640, 64))      # allocate memories for raw eeg
  tasks_s = np.empty((168,))
  reps_s = np.empty((168,))
  trails_s = np.empty((168,))
  trailReps_s = np.empty((168,))
  for i_f, f in enumerate(fileNames):
    cnt_t1 = 0
    cnt_t2 = 0
    trial_ind = -1       # valid trial counts
    if f not in ['{}R01.edf'.format(subject_str), '{}R02.edf'.format(subject_str)]:
      print(f)
      data = mne.io.read_raw_edf(os.path.join(dataPath, dataFolder_s, f))
      raw_eeg = data.get_data().T
      trials = np.array(data.annotations)

      # define task labels
      if i_f % 4 == 2:
        task = 1
      elif i_f % 4 == 3:
        task = 2
      elif i_f % 4 == 0:
        task = 3
      else:
        task = 4

      # define repetition labels
      if i_f <= 5:
        rep = 1
      elif i_f <= 9:
        rep = 2
      else:
        rep = 3

      trail_reps = []
      for i_trial, trial in enumerate(trials):
        items = list(trial.items())
        onset_ind = int(items[0][1] * sr)
        duration = items[1][1]
        description = items[2][1]
        if description == 'T1':
          cnt_t1 += 1
          trial_lbl = 1
          trial_ind += 1
          if cnt_t1 <= 7:
            trail_reps.append(cnt_t1)
        elif description == 'T2':
          cnt_t2 += 1
          trial_lbl = 2
          trial_ind += 1
          if cnt_t2 <= 7:
            trail_reps.append(cnt_t2)

        # check if T1 or T2 exceeds 7 trials
        if cnt_t1 <= 7 and cnt_t2 <= 7 and description != 'T0':
          # load first 4s data of each trial
          raw_eeg_trial = raw_eeg[onset_ind:onset_ind+640, :]
          raw_eeg_s[trial_ind+start_ind[i_f-2]] = raw_eeg_trial
          tasks_s[trial_ind+start_ind[i_f-2]] = task
          reps_s[trial_ind+start_ind[i_f-2]] = rep
          trails_s[trial_ind+start_ind[i_f-2]] = trial_lbl
      trailReps_s[(i_f-2)*14:(i_f-1)*14] = trail_reps

  return raw_eeg_s, tasks_s, reps_s, trails_s, trailReps_s

# %% [markdown]
# # Load and concatenate data

# %%
raw_eeg = np.empty((17808, 640, 64))
tasks = np.empty((17808,))
reps = np.empty((17808,))
trials = np.empty((17808,))
trial_reps = np.empty((17808,))
subs = np.empty((17808,))
start_ind = list(range(0, 17809, 168))        # start index of each subject
n_subject = 0

subjects = list(range(1, 110))
for subject in subjects:
  
  # skip problematic subjects
  if subject in [100, 104, 106]:
    continue
  
  raw_eeg_s, tasks_s, reps_s, trails_s, trailReps_s = loadEEG(subject)
  raw_eeg[start_ind[n_subject]:start_ind[n_subject]+168] = raw_eeg_s
  tasks[start_ind[n_subject]:start_ind[n_subject]+168] = tasks_s
  reps[start_ind[n_subject]:start_ind[n_subject]+168] = reps_s
  trials[start_ind[n_subject]:start_ind[n_subject]+168] = trails_s
  subs[start_ind[n_subject]:start_ind[n_subject]+168] = np.ones(168) * subject
  trial_reps[start_ind[n_subject]:start_ind[n_subject]+168] = trailReps_s
  n_subject += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S027R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S027/S027R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S027R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S027/S027R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S027R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S027/S027R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S027R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S027/S027R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 28 loading ...
#
# S028R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S028R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S028/S028R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 29 loading ...
#
# S029R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S029R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S029/S029R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 30 loading ...
#
# S030R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S030R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S030/S030R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 31 loading ...
#
# S031R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S031R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S031/S031R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 32 loading ...
#
# S032R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S032R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S032/S032R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 33 loading ...
#
# S033R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S033R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S033/S033R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 34 loading ...
#
# S034R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S034R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S034/S034R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 35 loading ...
#
# S035R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S035R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S035/S035R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 36 loading ...
#
# S036R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S036R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S036/S036R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 37 loading ...
#
# S037R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S037R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S037/S037R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 38 loading ...
#
# S038R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S038R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S038/S038R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 39 loading ...
#
# S039R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S039R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S039/S039R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 40 loading ...
#
# S040R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S040R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S040/S040R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 41 loading ...
#
# S041R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S041R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S041/S041R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 42 loading ...
#
# S042R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S042R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S042/S042R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 43 loading ...
#
# S043R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S043R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S043/S043R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 44 loading ...
#
# S044R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S044R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S044/S044R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 45 loading ...
#
# S045R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S045R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S045/S045R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 46 loading ...
#
# S046R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S046R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S046/S046R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 47 loading ...
#
# S047R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S047/S047R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S047R11.edf
# ...
# Setting channel info structure...
# Creating raw.info structure...
# S101R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S101R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S101/S101R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 102 loading ...
#
# S102R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S102R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S102/S102R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 103 loading ...
#
# S103R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S103R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S103/S103R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 105 loading ...
#
# S105R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S105R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S105/S105R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 107 loading ...
#
# S107R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S107R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S107/S107R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 108 loading ...
#
# S108R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S108R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S108/S108R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
#  Subject 109 loading ...
#
# S109R03.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R04.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R05.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R06.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R07.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R08.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R09.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R10.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R11.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R12.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R13.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# S109R14.edf
# Extracting EDF parameters from /content/drive/MyDrive/ECE-GY_9123_DL/project/data/S109/S109R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
f_data = h5py.File("./project/raw_EEG.h5", "w")
f_data.create_dataset("data", data=raw_eeg)
f_data.create_dataset("tasks", data=tasks)
f_data.create_dataset("reps", data=reps)
f_data.create_dataset("trials", data=trials)
f_data.create_dataset("trial_reps", data=trial_reps)
f_data.create_dataset("subjects", data=subs)
f_data.close()
